# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
show tables;
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
sql_query_import_1 = '''
create or replace table parking_violation_codes as
select
     *
from read_csv_auto(
'data/violation_codes.csv',
normalize_names=True
)
'''

sql_query_import_2 = '''
create or replace table parking_violations_2020 as
select
     *
from read_csv_auto(
'data/violations.csv',
normalize_names=True
)
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    con.sql(sql_query_import_1)
    con.sql(sql_query_import_2)
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[3], line 21
#       1 sql_query_import_1 = '''
#       2 create or replace table parking_violation_codes as
#       3 select
#    (...)      8 )
#       9 '''
#      11 sql_query_import_2 = '''
#      12 create or replace table parking_violations_2020 as
#      13 select
#    (...)     18 )
#      19 '''
# ---> 21 with duckdb.connect('data/nyc_parking_violations.db') as con:
#      22     con.sql(sql_query_import_1)
#      23     con.sql(sql_query_import_2)
#
# Cell In[3], line 22
#      11 sql_query_import_2 = '''
#      12 create or replace table parking_violations_2020 as
#      13 select
#    (...)     18 )
#      19 '''
#      21 with duckdb.connect('data/nyc_parking_violations.db') as con:
# ---> 22     con.sql(sql_query_import_1)
#      23     con.sql(sql_query_import_2)
#
# ParserException: Parser Error: unterminated quoted string at or near "'data/violation_codes.csv,
# normalize_names=True
# )
# "
#
# LINE 6: 'data/violation_codes.csv,
#         ^
